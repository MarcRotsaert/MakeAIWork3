# %%
#werkt niet
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': '{subscription key}',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('gateway.apiportal.ns.nl')
    conn.request("GET", "/Stationsplattegrond/Stations?returnGeometry={returnGeometry}&outSR={outSR}&returnCountOnly={returnCountOnly}&resultRecordCount={resultRecordCount}&resultOffset={resultOffset}&%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
#werkt ook niet
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': '{2bdd0637a8a64de1b88fbb0631c88bf6}',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('gateway.apiportal.ns.nl')
    conn.request("GET", "/Stationsplattegrond/Stations?returnGeometry={returnGeometry}&outSR={outSR}&returnCountOnly={returnCountOnly}&resultRecordCount={resultRecordCount}&resultOffset={resultOffset}&%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
# dit werkt wel
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': '2bdd0637a8a64de1b88fbb0631c88bf6',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('gateway.apiportal.ns.nl')
    conn.request("GET", "/Stationsplattegrond/Perronwand?returnGeometry={returnGeometry}&outSR={outSR}&returnCountOnly={returnCountOnly}&resultRecordCount={resultRecordCount}&resultOffset={resultOffset}&%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

####################################

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import scrapy
#
# ModuleNotFoundError: No module named 'scrapy'
