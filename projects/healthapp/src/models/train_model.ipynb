# %% [markdown]
# <h1> Training van het model lineaire regressie </h1>

# %%
import os
os.chdir(r'C:\Users\marcr\MakeAIWork3\projects\healthapp\src')
import models.train_model as tm
import data.database as db
import visualization.visualize as vs

# %%
colnames = ["bmi", "exercise", "smoking", "alcohol", "sugar", "lifespan"]
dfstat = db.dbdata2df(colnames)
yparam = colnames.pop(-1)
xparam = colnames

fitresult = tm.Modeltrainer(xparam=xparam, yparam=yparam).lineairregr(dfstat)
dfstat["pred"] = fitresult.predict(dfstat[xparam])
vs.Descrstats().plot_xygraph(dfstat, "lifespan", "pred")
vs.Descrstats().plot_xygraph(dfstat, "", "lifespan")
# Out:
# query
# query
# query
# query
# query
# query
# C:\Users\marcr\MakeAIWork3\projects\healthapp\src\visualization\visualize.py:32: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   pp.gcf().show()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\marcr\MakeAIWork3\env_miw3\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\marcr\MakeAIWork3\env_miw3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\marcr\MakeAIWork3\env_miw3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 9
#       7 dfstat["pred"] = fitresult.predict(dfstat[xparam])
#       8 vs.Descrstats().plot_xygraph(dfstat, "lifespan", "pred")
# ----> 9 vs.Descrstats().plot_xygraph(dfstat, "", "lifespan")
#
# File ~\MakeAIWork3\projects\healthapp\src\visualization\visualize.py:28, in Descrstats.plot_xygraph(self, df, xcol, ycol)
#      24 def plot_xygraph(self, df, xcol, ycol):
#      26     fig, ax = pp.subplots()
# ---> 28     pp.plot(df[xcol], df[ycol], ".", axes=ax)
#      29     # ax = pp.gca()
#      30     ax.set_xlabel(xcol)
#
# File c:\Users\marcr\MakeAIWork3\env_miw3\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File c:\Users\marcr\MakeAIWork3\env_miw3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: ''
